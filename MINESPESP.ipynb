# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - 1.17
# - 1.16.5
# - 1.16.4
# - 1.16.3
# - 1.15.2
# - 1.14.4
# - 1.13.2
# - 1.12.2
# - 1.11.2
# - 1.10.2
# - 1.9.4
# - 1.8.8


version = '1.20.1' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit)

server_type = 'paper'

#Importa librerias necesarias para el funcionamiento del script

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

if server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

if server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

if server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version
if server_type == 'fabric':
    serverURL = 'https://maven.fabricmc.net/net/fabricmc/fabric-installer/0.11.2/fabric-installer-0.11.2.jar'

if server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version

jar_name = {'paper': 'server.jar', 'fabric': 'fabric-installer.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-installer.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# https://papermc.io/api/v2/projects/paper/versions/1.20.1/builds/196/downloads/paper-1.20.1-196.jar
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# Completado!

# %%
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading



#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)



# Instalar OpenJDK


version = colabconfig["server_version"]

if colabconfig["server_version"] < "1.17":

    # !sudo apt-get purge openjdk* > /dev/null 2>&1

    # !sudo apt-get install openjdk-8-jre-headless &>/dev/null and print("OpenJDK 8 instalado!") or print("Error al intalar OpenJDK 8.")

else:

    # !sudo apt-get purge openjdk* > /dev/null 2>&1

    # !sudo apt-get install openjdk-17-jre-headless &>/dev/null and print("OpenJDK 17 instalado!") or print("Error al intalar OpenJDK 17.")


# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

if java_ver[0] == "17":

    print("Estas usando JAVA 17.")

else:

    print("Estas usando una version desactualizada de java. Puedo que Minecraft 1.17+ no funcione.")



#Lista de posibles archivos .jar


jar_list = {'paper': 'server.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar"}

jar_name = jar_list[colabconfig["server_type"]]



# Java arguments.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms6G -Xmx6G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "tu token aqui" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    #url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es potential-based.joinmc.link')

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))



print('Iniciando servidor...')

def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

if colabconfig["server_type"] == "forge":

    version = colabconfig["server_version"]

    if colabconfig["server_version"] < "1.17":

        oldpathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/forge-{version}-*.jar")

        if oldpathtoforge: # Checa si la lista no esta vacia

            path = oldpathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java $memory_allocation -jar "{path}" nogui

        else:

            print("No se encontro la version de Forge universal.")

    else:

        pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{version}-/unix_.txt")

        if pathtoforge: # Checa si la lista no esta vacia

            path = pathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java @user_jvm_args.txt "@{path}" "$@"

        else:

            print("No unix_args.txt found.")
else:

    # !java $memory_allocation $server_flags -jar $jar_name nogui



# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)
# Out:
# el apt cache fue actualizado correctamente
#  Minecraft-server		      paper-world-defaults.yml
# 'Server optimizations READ ME!.txt'   permissions.yml
#  banned-ips.json		      plugins
#  banned-players.json		      purpur.yml
#  bukkit.yml			      server-icon.png
#  cache				      server.jar
#  colabconfig.json		      server.properties
#  commands.yml			      spawn
#  config				      spigot.yml
#  configs			      start.bat
#  crash-reports			      test
#  eula.txt			      usercache.json
#  fancyanalytics_config.json	      version_history.json
#  help.yml			      versions
#  libraries			      wepif.yml
#  logs				      whitelist.json
#  map-color-cache.dat		      world
#  ops.json			      world_nether
#  paper-global.yml		      world_the_end
# /bin/bash: -c: line 0: syntax error near unexpected token `('
# /bin/bash: -c: line 0: `sudo apt-get install openjdk-17-jre-headless &>/dev/null and print("OpenJDK 17 instalado!") or print("Error al intalar OpenJDK 17.")'
# Estas usando una version desactualizada de java. Puedo que Minecraft 1.17+ no funcione.
# Usando ngrok
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# authtoken -
#
# USAGE:
#   ngrok authtoken TOKEN [flags]
#
# AUTHOR:
#   ngrok - <support@ngrok.com>
#
# COMMANDS:
#   config          update or migrate ngrok's configuration file
#   http            start an HTTP tunnel
#   tcp             start a TCP tunnel
#   tunnel          start a tunnel for use with a tunnel-group backend
#
# EXAMPLES:
#   ngrok http 80                                                 # secure public URL for port 80 web server
#   ngrok http --domain baz.ngrok.dev 8080                        # port 8080 available at baz.ngrok.dev
#   ngrok tcp 22                                                  # tunnel arbitrary TCP traffic to port 22
#   ngrok http 80 --oauth=google --oauth-allow-email=foo@foo.com  # secure your app with oauth
#
# Paid Features:
#   ngrok http 80 --domain mydomain.com                           # run ngrok with your own custom domain
#   ngrok http 80 --allow-cidr 2600:8c00::a03c:91ee:fe69:9695/32  # run ngrok with IP policy restrictions
#   Upgrade your account at https://dashboard.ngrok.com/billing/subscription to access paid features
#
# Upgrade your account at https://dashboard.ngrok.com/billing/subscription to access paid features
#
# Flags:
#   -h, --help      help for ngrok
#
# Use "ngrok [command] --help" for more information about a command.
#
# ERROR:  accepts 1 arg(s), received 3
# La IP de tu servidor es potential-based.joinmc.link
# Iniciando servidor...
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Starting org.bukkit.craftbukkit.Main
# *** Warning, you've not updated in a while! ***
# *** Please download a new build as per instructions from https://papermc.io/downloads/paper ***
# System Info: Java 21 (OpenJDK 64-Bit Server VM 21.0.4+7-LTS) Host: Linux 6.5.0-1025-azure (amd64)
# Loading libraries, please wait...
# [22:00:04 INFO]: Environment: authHost='https://authserver.mojang.com', accountsHost='https://api.mojang.com', sessionHost='https://sessionserver.mojang.com', servicesHost='https://api.minecraftservices.com', name='PROD'
# [22:00:06 INFO]: Loaded 7 recipes
# [22:00:07 INFO]: Starting minecraft server version 1.20.1
# [22:00:07 INFO]: Loading properties
# [22:00:07 INFO]: This server is running Paper version git-Paper-196 (MC: 1.20.1) (Implementing API version 1.20.1-R0.1-SNAPSHOT) (Git: 773dd72)
# [22:00:08 INFO]: Server Ping Player Sample Count: 12
# [22:00:08 INFO]: Using 4 threads for Netty based IO
# [22:00:08 WARN]: [!] The timings profiler has been enabled but has been scheduled for removal from Paper in the future.
#     We recommend installing the spark profiler as a replacement: https://spark.lucko.me/
#     For more information please visit: https://github.com/PaperMC/Paper/issues/8948
# [22:00:08 INFO]: [ChunkTaskScheduler] Chunk system is using 1 I/O threads, 1 worker threads, and gen parallelism of 1 threads
# [22:00:08 INFO]: Default game type: SURVIVAL
# [22:00:08 INFO]: Generating keypair
# [22:00:08 INFO]: Starting Minecraft server on *:25565
# [22:00:08 INFO]: Using epoll channel type
# [22:00:08 INFO]: Paper: Using libdeflate (Linux x86_64) compression from Velocity.
# [22:00:08 INFO]: Paper: Using OpenSSL 1.1.x (Linux x86_64) cipher from Velocity.
# [22:00:09 INFO]: [SpigotLibraryLoader] [MythicMobs] Loading 4 libraries... please wait
# [22:00:09 INFO]: [SpigotLibraryLoader] [MythicMobs] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/kyori/adventure-api/4.16.0/adventure-api-4.16.0.jar
# [22:00:09 INFO]: [SpigotLibraryLoader] [MythicMobs] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/kyori/adventure-key/4.16.0/adventure-key-4.16.0.jar
# [22:00:09 INFO]: [SpigotLibraryLoader] [MythicMobs] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/kyori/examination-api/1.3.0/examination-api-1.3.0.jar
# [22:00:09 INFO]: [SpigotLibraryLoader] [MythicMobs] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/kyori/examination-string/1.3.0/examination-string-1.3.0.jar
# [22:00:09 INFO]: [SpigotLibraryLoader] [MythicMobs] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/org/jetbrains/annotations/24.1.0/annotations-24.1.0.jar
# [22:00:09 INFO]: [SpigotLibraryLoader] [MythicMobs] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/kyori/adventure-platform-bukkit/4.3.2/adventure-platform-bukkit-4.3.2.jar
# [22:00:09 INFO]: [SpigotLibraryLoader] [MythicMobs] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/kyori/adventure-platform-api/4.3.2/adventure-platform-api-4.3.2.jar
# [22:00:09 INFO]: [SpigotLibraryLoader] [MythicMobs] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/kyori/adventure-text-serializer-bungeecord/4.3.2/adventure-text-serializer-bungeecord-4.3.2.jar
# [22:00:09 INFO]: [SpigotLibraryLoader] [MythicMobs] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/kyori/adventure-text-serializer-legacy/4.13.1/adventure-text-serializer-legacy-4.13.1.jar
# [22:00:09 INFO]: [SpigotLibraryLoader] [MythicMobs] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/kyori/adventure-nbt/4.13.1/adventure-nbt-4.13.1.jar
# [22:00:09 INFO]: [SpigotLibraryLoader] [MythicMobs] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/kyori/adventure-text-serializer-gson-legacy-impl/4.13.1/adventure-text-serializer-gson-legacy-impl-4.13.1.jar
# [22:00:09 INFO]: [SpigotLibraryLoader] [MythicMobs] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/kyori/adventure-platform-facet/4.3.2/adventure-platform-facet-4.3.2.jar
# [22:00:09 INFO]: [SpigotLibraryLoader] [MythicMobs] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/kyori/adventure-platform-viaversion/4.3.2/adventure-platform-viaversion-4.3.2.jar
# [22:00:09 INFO]: [SpigotLibraryLoader] [MythicMobs] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/kyori/adventure-text-minimessage/4.16.0/adventure-text-minimessage-4.16.0.jar
# [22:00:09 INFO]: [SpigotLibraryLoader] [MythicMobs] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/kyori/adventure-text-serializer-gson/4.16.0/adventure-text-serializer-gson-4.16.0.jar
# [22:00:09 INFO]: [SpigotLibraryLoader] [MythicMobs] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/kyori/adventure-text-serializer-json/4.16.0/adventure-text-serializer-json-4.16.0.jar
# [22:00:09 INFO]: [SpigotLibraryLoader] [MythicMobs] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/kyori/option/1.0.0/option-1.0.0.jar
# [22:00:09 INFO]: [SpigotLibraryLoader] [MythicMobs] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/com/google/code/gson/gson/2.8.0/gson-2.8.0.jar
# [22:00:09 INFO]: [SpigotLibraryLoader] [NexEngine] Loading 2 libraries... please wait
# [22:00:09 INFO]: [SpigotLibraryLoader] [NexEngine] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/com/zaxxer/HikariCP/5.0.1/HikariCP-5.0.1.jar
# [22:00:09 INFO]: [SpigotLibraryLoader] [NexEngine] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/org/slf4j/slf4j-api/2.0.0-alpha1/slf4j-api-2.0.0-alpha1.jar
# [22:00:09 INFO]: [SpigotLibraryLoader] [NexEngine] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/it/unimi/dsi/fastutil/8.5.11/fastutil-8.5.11.jar
# [22:00:09 INFO]: [WolfyUtilities] NMS Version: v1_20_R1
# [22:00:10 INFO]: [me.wolfyscript.lib.org.reflections.Reflections] Reflections took 487 ms to scan 1 urls, producing 1033 keys and 4039 values
# [22:00:10 INFO]: [WolfyUtilities] Register Default StackIdentifiers
# [22:00:10 INFO]: [SpigotLibraryLoader] [O'DailyQuests] Loading 2 libraries... please wait
# [22:00:10 INFO]: [SpigotLibraryLoader] [O'DailyQuests] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/com/zaxxer/HikariCP/5.0.1/HikariCP-5.0.1.jar
# [22:00:10 INFO]: [SpigotLibraryLoader] [O'DailyQuests] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/org/slf4j/slf4j-api/2.0.0-alpha1/slf4j-api-2.0.0-alpha1.jar
# [22:00:10 INFO]: [SpigotLibraryLoader] [O'DailyQuests] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/com/h2database/h2/2.1.214/h2-2.1.214.jar
# [22:00:10 INFO]: [SpigotLibraryLoader] [nightcore] Loading 2 libraries... please wait
# [22:00:10 INFO]: [SpigotLibraryLoader] [nightcore] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/com/zaxxer/HikariCP/5.0.1/HikariCP-5.0.1.jar
# [22:00:10 INFO]: [SpigotLibraryLoader] [nightcore] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/org/slf4j/slf4j-api/2.0.0-alpha1/slf4j-api-2.0.0-alpha1.jar
# [22:00:10 INFO]: [SpigotLibraryLoader] [nightcore] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/it/unimi/dsi/fastutil-core/8.5.13/fastutil-core-8.5.13.jar
# [22:00:10 INFO]: [SpigotLibraryLoader] [ChatImage] Loading 1 libraries... please wait
# [22:00:10 INFO]: [SpigotLibraryLoader] [ChatImage] Loaded library /workspaces/codespaces-jupyter/Minecraft-server/libraries/com/google/code/gson/gson/2.10.1/gson-2.10.1.jar
# [22:00:10 INFO]: [AngelChest] Hooked into WorldGuard 7.0.9+5934e49
# [22:00:11 INFO]: [CustomCrafting] NMS Version: v1_20_R1
# [22:00:11 INFO]: [ViaVersion] Loading server plugin ViaVersion v5.0.3
# [22:00:11 INFO]: [ViaVersion] ViaVersion 5.0.3 is now loaded. Registering protocol transformers and injecting...
# [22:00:11 INFO]: [ViaVersion] Loading block connection mappings ...
# [22:00:11 INFO]: [ViaVersion] Using FastUtil Long2ObjectOpenHashMap for block connections
# [22:00:11 INFO]: [LuckPerms] Loading server plugin LuckPerms v5.4.102
# [22:00:12 INFO]: [Vault] Loading server plugin Vault v1.7.3-b131
# [22:00:12 INFO]: [WorldEdit] Loading server plugin WorldEdit v7.2.20+6667-f0f1e66
# [22:00:12 INFO]: Got request to register class com.sk89q.worldedit.bukkit.BukkitServerInterface with WorldEdit [com.sk89q.worldedit.extension.platform.PlatformManager@7a463326]
# [22:00:12 INFO]: [VoidGen] Loading server plugin VoidGen v2.2.1
# [22:00:12 INFO]: [PlaceholderAPI] Loading server plugin PlaceholderAPI v2.11.6
# [22:00:12 INFO]: [WorldGuard] Loading server plugin WorldGuard v7.0.9+5934e49
# [22:00:12 INFO]: [Multiverse-Core] Loading server plugin Multiverse-Core v4.3.11
# [22:00:12 INFO]: [HolographicDisplays] Loading server plugin HolographicDisplays v3.0.4
# [22:00:12 INFO]: [ShopGUIPlus] Loading server plugin ShopGUIPlus v1.94.0
# [22:00:12 INFO]: [MythicMobs] Loading server plugin MythicMobs v5.7.2-${CI_COMMIT_SHORT_SHA}
# [22:00:12 INFO]: [LumineUtils] (io.lumine.mythic.bukkit.utils.) is bound to plugin MythicMobs - io.lumine.mythic.bukkit.MythicBukkit
# [22:00:12 INFO]: [MythicMobs] §x§f§f§0§0§0§0M§x§f§f§6§6§0§0y§x§f§f§c§c§0§0t§x§c§b§f§f§0§0h§x§6§5§f§f§0§0i§x§0§0§f§f§0§0c§x§0§0§f§f§6§6 §x§0§0§f§f§c§bE§x§0§0§c§b§f§fn§x§0§0§6§5§f§fa§x§0§0§0§0§f§fb§x§6§6§0§0§f§fl§x§c§c§0§0§f§fe§x§f§f§0§0§c§cd§x§f§f§0§0§6§6!
# [22:00:12 INFO]: [ProtocolLib] Loading server plugin ProtocolLib v5.2.0-SNAPSHOT-679
# [22:00:13 INFO]: [Essentials] Loading server plugin Essentials v2.20.1
# [22:00:13 INFO]: [CMILib] Loading server plugin CMILib v1.5.1.0
# [22:00:13 INFO]: [ItemEdit] Loading server plugin ItemEdit v3.4.2
# [22:00:13 INFO]: [DeluxeTags] Loading server plugin DeluxeTags v1.8.2-Release
# [22:00:13 INFO]: [NexEngine] Loading server plugin NexEngine v2.2.12
# [22:00:13 INFO]: [FancyNpcs] Loading server plugin FancyNpcs v2.2.0.175
# [22:00:13 INFO]: [WolfyUtilities] Loading server plugin WolfyUtilities v4.16.15
# [22:00:13 INFO]: [WolfyUtilities] Register JSON de-/serializers
# [22:00:13 INFO]: [WolfyUtilities] Register JSON Operators
# [22:00:13 INFO]: [WolfyUtilities] Register JSON Value Providers
# [22:00:13 INFO]: [WolfyUtilities] Register CustomItem NBT Checks
# [22:00:13 INFO]: [WolfyUtilities] Register CustomItem Actions
# [22:00:13 INFO]: [WolfyUtilities] Register CustomItem Events
# [22:00:13 INFO]: [WolfyUtilities] Register Particle Animators
# [22:00:13 INFO]: [WolfyUtilities] Register Particle Shapes
# [22:00:13 INFO]: [WolfyUtilities] Register Particle Timers
# [22:00:13 INFO]: [WolfyUtilities] Register Custom Block Data
# [22:00:13 INFO]: [WolfyUtilities] Register Custom Player Data
# [22:00:13 INFO]: [WolfyUtilities] Register NBT Query Nodes
# [22:00:13 INFO]: [SkinsRestorer] Loading server plugin SkinsRestorer v15.4.3
# [22:00:13 INFO]: [YamipaPlugin] Loading server plugin YamipaPlugin v1.3.1
# [22:00:13 INFO]: [O'DailyQuests] Loading server plugin ODailyQuests v2.2.5
# [22:00:13 INFO]: [Tebex] Loading server plugin Tebex v2.0.5
# [22:00:13 INFO]: [DeluxeMenus] Loading server plugin DeluxeMenus v1.14.0-Release
# [22:00:13 INFO]: [DeluxeMenus] NMS hook has been setup successfully!
# [22:00:13 INFO]: [Jobs] Loading server plugin Jobs v5.2.4.3
# [22:00:13 INFO]: [EasyCommandBlocker] Loading server plugin EasyCommandBlocker v1.9.3
# [22:00:13 INFO]: [TAB] Loading server plugin TAB v4.0.3
# [22:00:13 INFO]: [nightcore] Loading server plugin nightcore v2.5.2
# [22:00:13 INFO]: [BetterRTP] Loading server plugin BetterRTP v3.6.13
# [22:00:13 INFO]: [ProtectionStones] Loading server plugin ProtectionStones v2.10.3
# [22:00:13 INFO]: [ChatImage] Loading server plugin ChatImage v2.7.0
# [22:00:13 INFO]: [AngelChest] Loading server plugin AngelChest v13.6.1
# [22:00:14 INFO]: [AngelChest] Successfully registered WorldGuard flags.
# [22:00:14 INFO]: [EssentialsSpawn] Loading server plugin EssentialsSpawn v2.20.1
# [22:00:14 INFO]: [HeadDB] Loading server plugin HeadDB v5.0.0-rc.7
# [22:00:14 INFO]: [PlayerKits2] Loading server plugin PlayerKits2 v1.12.4
# [22:00:14 INFO]: [BetterTeams] Loading server plugin BetterTeams v4.9.4
# [22:00:14 INFO]: [BetterTeams] Checking if the file config.yml is up to date
# [22:00:14 INFO]: [BetterTeams] File is up to date
# [22:00:14 INFO]: [ItemTag] Loading server plugin ItemTag v3.4.2
# [22:00:14 INFO]: [SilkSpawners_v2] Loading server plugin SilkSpawners_v2 v2.3.1
# [22:00:14 INFO]: [ChatManager] Loading server plugin ChatManager v3.7.7
# [22:00:14 INFO]: [DailyRewardsPlus] Loading server plugin DailyRewardsPlus v1.3.3
# [22:00:14 INFO]: [CommandBlocks] Loading server plugin CommandBlocks v1.3.2
# [22:00:14 INFO]: [CustomDeathMessages] Loading server plugin CustomDeathMessages v2.0.1
# [22:00:14 INFO]: [ExcellentCrates] Loading server plugin ExcellentCrates v5.0.0
# [22:00:14 INFO]: [playit-gg] Loading server plugin playit-gg v0.1.4
# [22:00:14 INFO]: [FancyHolograms] Loading server plugin FancyHolograms v2.3.3
# [22:00:14 INFO]: [ConditionalEvents] Loading server plugin ConditionalEvents v4.57.3
# [22:00:14 INFO]: [Chunky] Loading server plugin Chunky v1.3.146
# [22:00:14 INFO]: [ClearLag] Loading server plugin ClearLag v3.2.2
# [22:00:14 INFO]: [LuckyTreasure] Loading server plugin LuckyTreasure v4.2
# [22:00:14 INFO]: [nLogin] Loading server plugin nLogin v10.3.28
# [22:00:14 INFO]: [CustomCrafting] Loading server plugin CustomCrafting v4.16.9
# [22:00:14 INFO]: [CustomCrafting] WolfyUtils API: v4.16.15
# [22:00:14 INFO]: [CustomCrafting] CustomCrafting: v4.16.9
# [22:00:14 INFO]: [CustomCrafting] Environment   : PROD
# [22:00:14 INFO]: [CustomCrafting] Registering CustomItem Data
# [22:00:14 INFO]: [CustomCrafting] Registering Custom Block Data
# [22:00:14 INFO]: [CustomCrafting] Registering Result Extensions
# [22:00:14 INFO]: [CustomCrafting] Registering Result Merge Adapters
# [22:00:14 INFO]: [CustomCrafting] Registering Recipe Conditions
# [22:00:14 INFO]: [CustomCrafting] Registering Recipe Types
# [22:00:14 INFO]: [CustomCrafting] Registering Anvil Recipe Tasks
# [22:00:14 INFO]: [CustomCrafting] Registering Type Registries
# [22:00:14 INFO]: [ajLeaderboards] Loading server plugin ajLeaderboards v2.9.0
# [22:00:14 INFO]: [ajLeaderboards] Verifying checksum for gson
# [22:00:14 INFO]: [ajLeaderboards] Checksum matched for gson
# [22:00:14 INFO]: [ajLeaderboards] Verifying checksum for jar-relocator
# [22:00:14 INFO]: [ajLeaderboards] Checksum matched for jar-relocator
# [22:00:14 INFO]: [ajLeaderboards] Verifying checksum for asm
# [22:00:14 INFO]: [ajLeaderboards] Checksum matched for asm
# [22:00:14 INFO]: [ajLeaderboards] Verifying checksum for asm-commons
# [22:00:14 INFO]: [ajLeaderboards] Checksum matched for asm-commons
# [22:00:15 INFO]: [ajLeaderboards] Verifying checksum for gson
# [22:00:15 INFO]: [ajLeaderboards] Checksum matched for gson
# [22:00:15 INFO]: [ajLeaderboards] Verifying checksum for HikariCP
# [22:00:15 INFO]: [ajLeaderboards] Checksum matched for HikariCP
# [22:00:15 INFO]: [ajLeaderboards] Verifying checksum for slf4j-api
# [22:00:15 INFO]: [ajLeaderboards] Checksum matched for slf4j-api
# [22:00:15 INFO]: [ajLeaderboards] Verifying checksum for h2
# [22:00:15 INFO]: [ajLeaderboards] Checksum matched for h2
# [22:00:15 INFO]: [ajLeaderboards] Verifying checksum for okhttp
# [22:00:15 INFO]: [ajLeaderboards] Checksum matched for okhttp
# [22:00:15 INFO]: [ajLeaderboards] Verifying checksum for okio
# [22:00:15 INFO]: [ajLeaderboards] Checksum matched for okio
# [22:00:15 INFO]: [ajLeaderboards] Verifying checksum for okio-jvm
# [22:00:15 INFO]: [ajLeaderboards] Checksum matched for okio-jvm
# [22:00:15 INFO]: [ajLeaderboards] Verifying checksum for kotlin-stdlib-jdk8
# [22:00:15 INFO]: [ajLeaderboards] Checksum matched for kotlin-stdlib-jdk8
# [22:00:15 INFO]: [ajLeaderboards] Verifying checksum for kotlin-stdlib
# [22:00:15 INFO]: [ajLeaderboards] Checksum matched for kotlin-stdlib
# [22:00:15 INFO]: [ajLeaderboards] Verifying checksum for kotlin-stdlib-common
# [22:00:15 INFO]: [ajLeaderboards] Checksum matched for kotlin-stdlib-common
# [22:00:15 INFO]: [ajLeaderboards] Verifying checksum for annotations
# [22:00:15 INFO]: [ajLeaderboards] Checksum matched for annotations
# [22:00:15 INFO]: [ajLeaderboards] Verifying checksum for kotlin-stdlib-jdk7
# [22:00:15 INFO]: [ajLeaderboards] Checksum matched for kotlin-stdlib-jdk7
# [22:00:15 INFO]: [AuctionHouse] Loading server plugin AuctionHouse v3.5
# [22:00:15 INFO]: [CommandPanels] Loading server plugin CommandPanels v3.21.4.2
# [22:00:15 INFO]: [AuraSkills] Loading server plugin AuraSkills v2.2.3
# [22:00:15 INFO]: [PluginPortal] Loading server plugin PluginPortal v2.0.4
# [22:00:15 INFO]: Server permissions file permissions.yml is empty, ignoring it
# [22:00:15 INFO]: [LuckPerms] Enabling LuckPerms v5.4.102
# [22:00:15 ERROR]: [LuckPerms] [STDERR] SLF4J: No SLF4J providers were found.
# [22:00:15 WARN]: Nag author(s): '[Luck]' of 'LuckPerms v5.4.102' about their usage of System.out/err.print. Please use your plugin's logger instead (JavaPlugin#getLogger).
# [22:00:15 ERROR]: [LuckPerms] [STDERR] SLF4J: Defaulting to no-operation (NOP) logger implementation
# [22:00:15 ERROR]: [LuckPerms] [STDERR] SLF4J: See http://www.slf4j.org/codes.html#noProviders for further details.
# [22:00:16 INFO]:         __
# [22:00:16 INFO]:   |    |__)   LuckPerms v5.4.102
# [22:00:16 INFO]:   |___ |      Running on Bukkit - Paper
# [22:00:16 INFO]:
# [22:00:16 INFO]: [LuckPerms] Loading configuration...
# [22:00:16 INFO]: [LuckPerms] Loading storage provider... [H2]
# [22:00:17 INFO]: [LuckPerms] Loading internal permission managers...
# [22:00:17 INFO]: [LuckPerms] Performing initial data load...
# [22:00:17 INFO]: [LuckPerms] Successfully enabled. (took 2008ms)
# [22:00:17 INFO]: [Vault] Enabling Vault v1.7.3-b131
# [22:00:18 INFO]: [Vault] [Economy] Essentials Economy found: Waiting
# [22:00:18 INFO]: [Vault] [Permission] SuperPermissions loaded as backup permission system.
# [22:00:18 INFO]: [Vault] Enabled Version 1.7.3-b131
# [22:00:18 INFO]: [LuckPerms] Registered Vault permission & chat hook.
# [22:00:18 INFO]: [WorldEdit] Enabling WorldEdit v7.2.20+6667-f0f1e66
# [22:00:18 INFO]: Registering commands with com.sk89q.worldedit.bukkit.BukkitServerInterface
# [22:00:18 INFO]: WEPIF: Vault detected! Using Vault for permissions
# [22:00:18 INFO]: Using com.sk89q.worldedit.bukkit.adapter.impl.v1_20_R1.PaperweightAdapter as the Bukkit adapter
# [22:00:19 INFO]: [VoidGen] Enabling VoidGen v2.2.1
# [22:00:20 INFO]: [VoidGen] Using VoidChunkGen: VERSION_UNKNOWN
# [22:00:20 INFO]: [ProtocolLib] Enabling ProtocolLib v5.2.0-SNAPSHOT-679
# [22:00:20 INFO]: [NexEngine] Enabling NexEngine v2.2.12
# [22:00:20 INFO]: [NexEngine] Seems like we have Paper based fork here...
# [22:00:20 WARN]: [NexEngine] ==================================
# [22:00:20 WARN]: [NexEngine] WARNING: You're running an outdated/deprecated server version (1.20.1)!
# [22:00:20 WARN]: [NexEngine] Support for this version will be dropped soon.
# [22:00:20 WARN]: [NexEngine] Please, upgrade your server to at least 1.20.2.
# [22:00:20 WARN]: [NexEngine] ==================================
# [22:00:20 INFO]: [NexEngine] Successfully hooked with LuckPerms permissions
# [22:00:20 INFO]: [NexEngine] Successfully hooked with EssentialsX Economy economy
# [22:00:20 INFO]: [NexEngine] Successfully hooked with LuckPerms chat
# [22:00:21 INFO]: [NexEngine] Plugin loaded in 75 ms!
# [22:00:21 INFO]: [WolfyUtilities] Enabling WolfyUtilities v4.16.15
# [22:00:21 INFO]: [WolfyUtilities] Minecraft version: 1.20.1
# [22:00:21 INFO]: [WolfyUtilities] WolfyUtils version: 4.16.15.0
# [22:00:21 INFO]: [WolfyUtilities] Environment: PROD
# [22:00:21 INFO]: [WolfyUtilities] Loading Plugin integrations:
# [22:00:21 INFO]: [WolfyUtilities]  - MythicMobs
# [22:00:21 INFO]: [WolfyUtilities]  - PlaceholderAPI
# [22:00:21 INFO]: [WolfyUtilities] Create & Init Plugin integrations:
# [22:00:21 INFO]: [WolfyUtilities] Register API references
# [22:00:21 INFO]: [WolfyUtilities] Loading stored Custom Items
# [22:00:21 INFO]: [WolfyUtilities] Loading Creative Mode Tabs
# [22:00:21 INFO]: [SkinsRestorer] Enabling SkinsRestorer v15.4.3
# [22:00:21 WARN]: [SkinsRestorer] You must agree to the rules at 'commands.perSkinPermissionsConsent' in the config to use per skin permissions.
# [22:00:22 INFO]: [SkinsRestorer] Running on Minecraft 1.20.1.
# [22:00:22 INFO]: [SkinsRestorer] Using paper join listener!
# [22:00:22 INFO]: [PlaceholderAPI] Successfully registered internal expansion: skinsrestorer [15.4.3]
# [22:00:22 INFO]: [SkinsRestorer] PlaceholderAPI expansion registered!
# [22:00:22 INFO]: [nightcore] Enabling nightcore v2.5.2
# [22:00:22 INFO]: [SkinsRestorer] ----------------------------------------------
# [22:00:22 INFO]: [SkinsRestorer]     +==================+
# [22:00:22 INFO]: [SkinsRestorer]     |   SkinsRestorer  |
# [22:00:22 INFO]: [SkinsRestorer]     |------------------|
# [22:00:22 INFO]: [SkinsRestorer]     |  Standalone Mode |
# [22:00:22 INFO]: [SkinsRestorer]     +==================+
# [22:00:22 INFO]: [SkinsRestorer] ----------------------------------------------
# [22:00:22 INFO]: [SkinsRestorer]     Version: 15.4.3
# [22:00:22 INFO]: [SkinsRestorer]     Commit: 4aa9140
# [22:00:22 INFO]: [SkinsRestorer]     This is the latest version!
# [22:00:22 INFO]: [SkinsRestorer] ----------------------------------------------
# [22:00:22 INFO]: [SkinsRestorer] Do you have issues? Read our troubleshooting guide: https://skinsrestorer.net/docs/troubleshooting
# [22:00:22 INFO]: [SkinsRestorer] Want to support SkinsRestorer? Consider donating: https://skinsrestorer.net/donate
# [22:00:22 WARN]: [nightcore] ===================================
# [22:00:22 WARN]: [nightcore] WARNING: You're running an outdated/deprecated server version (1.20.1)!
# [22:00:22 WARN]: [nightcore] Support for this version will be dropped soon.
# [22:00:22 WARN]: [nightcore] Please, upgrade your server to at least 1.20.4.
# [22:00:22 WARN]: [nightcore] ===================================
# [22:00:22 INFO]: [nightcore] Found permissions provider: LuckPerms
# [22:00:22 INFO]: [nightcore] Found economy provider: EssentialsX Economy
# [22:00:22 INFO]: [nightcore] Found chat provider: LuckPerms
# [22:00:22 INFO]: [nightcore] Server Version: 1.20.1 (OK)
# [22:00:22 INFO]: [nightcore] Entity Id Counter: OK.
# [22:00:22 INFO]: [nightcore] Item NBT Compress: OK.
# [22:00:22 INFO]: [nightcore] Plugin loaded in 89 ms!
# [22:00:22 INFO]: [nLogin] Enabling nLogin v10.3.28
# [22:00:23 INFO]: [nLogin] Successful plugin core start (took 0.48s)
# [22:00:23 INFO]:           __             _
# [22:00:23 INFO]:   _ __   / /  ___   __ _(_)_ __
# [22:00:23 INFO]:  | '_ \ / /  / _ \ / _` | | '_ \
# [22:00:23 INFO]:  | | | / /__| (_) | (_| | | | | |
# [22:00:23 INFO]:  |_| |_\____/\___/ \__, |_|_| |_|
# [22:00:23 INFO]:                   |___/
# [22:00:23 INFO]:  By: www.nickuc.com - V 10.3.28
# [22:00:23 INFO]:
# [22:00:24 WARN]: **** SERVER IS RUNNING IN OFFLINE/INSECURE MODE!
# [22:00:24 WARN]: The server will make no attempt to authenticate usernames. Beware.
# [22:00:24 WARN]: While this makes the game possible to play without internet access, it also opens up the ability for hackers to connect with any username they choose.
# [22:00:24 WARN]: To change this, set "online-mode" to "true" in the server.properties file.
# [22:00:24 INFO]: Preparing level "world"
# [22:00:25 INFO]: Preparing start region for dimension minecraft:overworld
# [22:00:26 INFO]: Time elapsed: 241 ms
# [22:00:26 INFO]: Preparing start region for dimension minecraft:the_nether
# [22:00:26 INFO]: Time elapsed: 53 ms
# [22:00:26 INFO]: Preparing start region for dimension minecraft:the_end
# [22:00:26 INFO]: Time elapsed: 94 ms
# [22:00:26 INFO]: [ViaVersion] Enabling ViaVersion v5.0.3
# [22:00:26 INFO]: [ViaVersion] ViaVersion detected server version: 1.20-1.20.1 (763)
# [22:00:26 INFO]: [PlaceholderAPI] Enabling PlaceholderAPI v2.11.6
# [22:00:27 INFO]: [PlaceholderAPI] Fetching available expansion information...
# [22:00:27 INFO]: [WolfyUtilities] init PAPI event
# [22:00:27 INFO]: [WolfyUtilities] Enabled plugin integration for PlaceholderAPI
# [22:00:27 INFO]: [WorldGuard] Enabling WorldGuard v7.0.9+5934e49
# [22:00:28 INFO]: [WorldGuard] (world) TNT ignition is PERMITTED.
# [22:00:28 INFO]: [WorldGuard] (world) Lighters are PERMITTED.
# [22:00:28 INFO]: [WorldGuard] (world) Lava fire is PERMITTED.
# [22:00:28 INFO]: [WorldGuard] (world) Fire spread is UNRESTRICTED.
# [22:00:28 INFO]: [WorldGuard] Loaded configuration for world 'world'
# [22:00:28 INFO]: [WorldGuard] (world_nether) TNT ignition is PERMITTED.
# [22:00:28 INFO]: [WorldGuard] (world_nether) Lighters are PERMITTED.
# [22:00:28 INFO]: [WorldGuard] (world_nether) Lava fire is PERMITTED.
# [22:00:28 INFO]: [WorldGuard] (world_nether) Fire spread is UNRESTRICTED.
# [22:00:28 INFO]: [WorldGuard] Loaded configuration for world 'world_nether'
# [22:00:28 INFO]: [WorldGuard] (world_the_end) TNT ignition is PERMITTED.
# [22:00:28 INFO]: [WorldGuard] (world_the_end) Lighters are PERMITTED.
# [22:00:28 INFO]: [WorldGuard] (world_the_end) Lava fire is PERMITTED.
# [22:00:28 INFO]: [WorldGuard] (world_the_end) Fire spread is UNRESTRICTED.
# [22:00:28 INFO]: [WorldGuard] Loaded configuration for world 'world_the_end'
# [22:00:28 INFO]: [WorldGuard] Loading region data...
# [22:00:28 INFO]: [Multiverse-Core] Enabling Multiverse-Core v4.3.11
# [22:00:28 WARN]: [Multiverse-Core] "Multiverse-Core v4.3.11" has registered a listener for org.bukkit.event.entity.EntityCreatePortalEvent on method "public void com.onarandombox.MultiverseCore.listeners.MVPortalListener.entityPortalCreate(org.bukkit.event.entity.EntityCreatePortalEvent)", but the event is Deprecated. "Server performance will be affected"; please notify the authors [dumptruckman, Rigby, fernferret, lithium3141, main--].
# [22:00:28 INFO]: [Multiverse-Core] §aWe are aware of the warning about the deprecated event. There is no alternative that allows us to do what we need to do and performance impact is negligible. It is safe to ignore.
# [22:00:28 WARN]: [Multiverse-Core] Exception while loading value for environment
# [22:00:28 WARN]: [Multiverse-Core] Exception while loading value for environment
# [22:00:29 WARN]: [Multiverse-Core] WorldManager: Can't load this world because the folder was deleted/moved: parcelas
# [22:00:29 WARN]: [Multiverse-Core] Use '/mv remove' to remove it from the config!
# [22:00:29 INFO]: [VoidGen] Generator settings "." syntax is not valid. Using default values:
# [22:00:29 INFO]: [VoidGen] {"caves":false,"decoration":false,"mobs":false,"structures":false,"noise":false,"surface":false,"bedrock":false}
# [22:00:29 INFO]: Preparing start region for dimension minecraft:spawn
# [22:00:29 INFO]: Time elapsed: 788 ms
# [22:00:29 INFO]: [WorldGuard] (spawn) TNT ignition is PERMITTED.
# [22:00:29 INFO]: [WorldGuard] (spawn) Lighters are PERMITTED.
# [22:00:29 INFO]: [WorldGuard] (spawn) Lava fire is PERMITTED.
# [22:00:29 INFO]: [WorldGuard] (spawn) Fire spread is UNRESTRICTED.
# [22:00:29 INFO]: [WorldGuard] Loaded configuration for world 'spawn'
# [22:00:30 INFO]: [VoidGen] Generator settings "." syntax is not valid. Using default values:
# [22:00:30 INFO]: [VoidGen] {"caves":false,"decoration":false,"mobs":false,"structures":false,"noise":false,"surface":false,"bedrock":false}
# [22:00:30 INFO]: Could not set generator for world 'test': Plugin 'PlotSquared' does not exist
# [22:00:30 ERROR]: Could not set generator for default world 'test': Plugin 'PlotSquared' does not exist
# [22:00:30 INFO]: Preparing start region for dimension minecraft:test
# [22:00:30 INFO]: Time elapsed: 78 ms
# [22:00:30 INFO]: [WorldGuard] (test) TNT ignition is PERMITTED.
# [22:00:30 INFO]: [WorldGuard] (test) Lighters are PERMITTED.
# [22:00:30 INFO]: [WorldGuard] (test) Lava fire is PERMITTED.
# [22:00:30 INFO]: [WorldGuard] (test) Fire spread is UNRESTRICTED.
# [22:00:30 INFO]: [WorldGuard] Loaded configuration for world 'test'
# [22:00:30 INFO]: Could not set generator for world 'test': Plugin 'PlotSquared' does not exist
# [22:00:30 INFO]: [Multiverse-Core] 5 - World(s) loaded.
# [22:00:30 WARN]: [Multiverse-Core] Buscript failed to load! The script command will be disabled! If you would like not to see this message, use `/mv conf enablebuscript false` to disable Buscript from loading.
# [22:00:30 INFO]: [Multiverse-Core] Version 4.3.11 (API v24) Enabled - By dumptruckman, Rigby, fernferret, lithium3141 and main--
# [22:00:30 INFO]: [HolographicDisplays] Enabling HolographicDisplays v3.0.4
# [22:00:30 INFO]: [ShopGUIPlus] Enabling ShopGUIPlus v1.94.0
# [22:00:31 INFO]: [MythicMobs] Enabling MythicMobs v5.7.2-${CI_COMMIT_SHORT_SHA}
# [22:00:31 INFO]: [MythicMobs] Loading MythicMobs for Paper (MC: 1.20.1)...
# [22:00:31 INFO]: [MythicMobs] The server is running Paper; enabled Paper exclusive functionality
# [22:00:33 INFO]: [MythicMobs] Mythic HolographicDisplays Support has been enabled!
# [22:00:33 INFO]: [PlaceholderAPI] Successfully registered internal expansion: mythic [5.0.0]
# [22:00:34 INFO]: [MythicMobs] Mythic PlaceholderAPI Support has been enabled!
# [22:00:34 INFO]: [MythicMobs] Mythic ProtocolLib Support has been enabled!
# [22:00:34 INFO]: [MythicMobs] Mythic Vault Support has been enabled!
# [22:00:34 INFO]: [MythicMobs] Mythic WorldGuard Support has been enabled!
# [22:00:34 INFO]: [MythicMobs] Base directory /workspaces/codespaces-jupyter/Minecraft-server/plugins/MythicMobs/data
# [22:00:34 INFO]: [MythicMobs] Module directory /workspaces/codespaces-jupyter/Minecraft-server/plugins/MythicMobs/data/worlds
# [22:00:35 INFO]: [MythicMobs] Loading Packs...
# [22:00:36 INFO]: [MythicMobs] Loading Items...
# [22:00:36 INFO]: [MythicMobs] Loading Item Groups...
# [22:00:36 INFO]: [MythicMobs] Loading Skills...
# [22:00:36 INFO]: [MythicMobs] Loading Drop Tables...
# [22:00:36 INFO]: [MythicMobs] Loading Random Spawns...
# [22:00:36 INFO]: [MythicMobs] Loading Spawn Blocks...
# [22:00:36 INFO]: [MythicMobs] ✓ Loaded 8 mobs.
# [22:00:36 INFO]: [MythicMobs] ✓ Loaded 3 vanilla mob overrides.
# [22:00:36 INFO]: [MythicMobs] ✓ Loaded 0 mob stacks.
# [22:00:36 INFO]: [MythicMobs] ✓ Loaded 3 skills.
# [22:00:36 INFO]: [MythicMobs] ✓ Loaded 0 random spawns.
# [22:00:36 INFO]: [MythicMobs] ✓ Loaded 3 mythic items.
# [22:00:36 INFO]: [MythicMobs] ✓ Loaded 2 drop tables.
# [22:00:36 INFO]: [MythicMobs] ✓ Loaded 0 mob spawners.
# [22:00:36 INFO]: [MythicMobs] MythicMobs configuration file loaded successfully.
# [22:00:36 INFO]: [MythicMobs] Started up bStats Metrics
# [22:00:36 INFO]: [MythicMobs] ✓ MythicMobs v5.7.2 ( build ${CI_COMMIT_SHORT_SHA} ) has been successfully loaded!
# [22:00:36 INFO]: [WolfyUtilities] Enabled plugin integration for MythicMobs
# [22:00:36 INFO]: [Essentials] Enabling Essentials v2.20.1
# [22:00:37 INFO]: [Essentials] Attempting to convert old kits in config.yml to new kits.yml
# [22:00:37 INFO]: [Essentials] No kits found to migrate.
# [22:00:37 INFO]: [Essentials] Loaded 39094 items from items.json.
# [22:00:37 INFO]: [Essentials] Using locale en
# [22:00:37 INFO]: [Essentials] ServerListPingEvent: Spigot iterator API
# [22:00:37 INFO]: [Essentials] Starting Metrics. Opt-out using the global bStats config.
# [22:00:37 INFO]: [Vault] [Economy] Essentials Economy hooked.
# [22:00:37 INFO]: [Essentials] Using Vault based permissions (LuckPerms)
# [22:00:37 INFO]: [CMILib] Enabling CMILib v1.5.1.0
# [22:00:39 INFO]: Server version: v1_20_R1 - 1.20.1 - paper  git-Paper-196 (MC: 1.20.1)
# [22:00:39 INFO]: [PlaceholderAPI] Successfully registered internal expansion: cmil [1.5.1.0]
# [22:00:39 INFO]: PlaceholderAPI hooked.
# [22:00:39 INFO]: Updated (EN) language file. Took 34ms
# [22:00:39 INFO]: [ItemEdit] Enabling ItemEdit v3.4.2
# [22:00:40 INFO]: [ItemEdit] Selected Storage Type: YAML
# [22:00:40 INFO]: [ItemEdit] Hooking into Vault
# [22:00:40 INFO]: [ItemEdit] Hooking into PlaceholderApi
# [22:00:40 INFO]: [ItemEdit] Hooked into PlaceHolderAPI:
# [22:00:40 INFO]: [ItemEdit] placeholders:
# [22:00:40 INFO]: [ItemEdit]   %itemedit_amount_<{itemid}>_[{slot}]_[{player}]%
# [22:00:40 INFO]: [ItemEdit]     shows how many itemid player has on slot
# [22:00:40 INFO]: [ItemEdit]     <{itemid}> for item id on serveritem
# [22:00:40 INFO]: [ItemEdit]     [{slot}] for the slot where the item should be counted, by default inventory
# [22:00:40 INFO]: [ItemEdit]       Values: inventory (include offhand), equip (include offhand), inventoryandequip (include offhand), hand, offhand, head, chest, legs, feet
# [22:00:40 INFO]: [ItemEdit]     [{player}] for the player, by default self
# [22:00:40 INFO]: [ItemEdit]     example: %itemedit_amount_{my_item_id}_{hand}%
# [22:00:40 INFO]: [PlaceholderAPI] Successfully registered internal expansion: itemedit [1.0]
# [22:00:40 INFO]: [ItemEdit] Hooking into ShopGuiPlus
# [22:00:40 INFO]: [ShopGUIPlus] Registered item provider 'ServerItem'.
# [22:00:40 INFO]: [ItemEdit] Hooking into MythicMobs
# [22:00:40 INFO]: [ItemEdit] # Enabled (took 73 ms)
# [22:00:40 INFO]: [DeluxeTags] Enabling DeluxeTags v1.8.2-Release
# [22:00:40 INFO]: [DeluxeTags] Using standard hex colors format: #aaFF00
# [22:00:40 INFO]: [DeluxeTags] 69 tags loaded
# [22:00:40 INFO]: [DeluxeTags] Loading DeluxeTags messages.yml
# [22:00:40 INFO]: [DeluxeTags] PAPI Chat enabled. This means your chat plugin will use placeholders to fetch the tags!
# [22:00:40 INFO]: [PlaceholderAPI] Successfully registered internal expansion: deluxetags [1.8.2-Release]
# [22:00:40 INFO]: [DeluxeTags] ----------------------------
# [22:00:40 INFO]: [DeluxeTags]      DeluxeTags Updater
# [22:00:40 INFO]: [DeluxeTags]
# [22:00:40 INFO]: [DeluxeTags] You are running 1.8.2-Release
# [22:00:40 INFO]: [DeluxeTags] The latest version
# [22:00:40 INFO]: [DeluxeTags] of DeluxeTags!
# [22:00:40 INFO]: [DeluxeTags]
# [22:00:40 INFO]: [DeluxeTags] ----------------------------
# [22:00:40 INFO]: [FancyNpcs] Enabling FancyNpcs v2.2.0.175
# [22:00:41 INFO]: [YamipaPlugin] Enabling YamipaPlugin v1.3.1
# [22:00:41 WARN]: [FancyNpcs] -------------------------------------------------------
# [22:00:41 WARN]: [FancyNpcs] You are not using the latest version the FancyNpcs plugin.
# [22:00:41 WARN]: [FancyNpcs] Please update to the newest version (2.2.2).
# [22:00:41 WARN]: [FancyNpcs] https://modrinth.com/plugin/FancyNpcs
# [22:00:41 WARN]: [FancyNpcs] -------------------------------------------------------
# [22:00:41 INFO]: [YamipaPlugin] Enabled image animation support
# [22:00:41 INFO]: [O'DailyQuests] Enabling ODailyQuests v2.2.5
# [22:00:42 INFO]: [O'DailyQuests] Plugin is starting...
# [22:00:42 INFO]: [O'DailyQuests] Checking for update...
# [22:00:42 INFO]: [com.zaxxer.hikari.HikariDataSource] HikariPool-1 - Starting...
# [22:00:42 INFO]: [com.zaxxer.hikari.pool.HikariPool] HikariPool-1 - Added connection conn0: url=jdbc:h2:./plugins/ODailyQuests/database user=ODQ
# [22:00:42 INFO]: [com.zaxxer.hikari.HikariDataSource] HikariPool-1 - Start completed.
# [22:00:42 INFO]: [O'DailyQuests] Plugin successfully connected to database DATABASE.
# [22:00:42 INFO]: [O'DailyQuests] Vault successfully hooked.
# [22:00:42 INFO]: [O'DailyQuests] MythicMobs successfully hooked.
# [22:00:42 INFO]: [O'DailyQuests] HolographicDisplays successfully hooked.
# [22:00:42 INFO]: [PlaceholderAPI] Successfully registered internal expansion: odailyquests [1.0.4]
# [22:00:42 INFO]: [O'DailyQuests] PlaceholderAPI successfully hooked.
# [22:00:42 INFO]: [O'DailyQuests] Holograms successfully loaded.
# [22:00:42 INFO]: [O'DailyQuests] easyQuests array successfully loaded (11).
# [22:00:42 INFO]: [O'DailyQuests] mediumQuests array successfully loaded (9).
# [22:00:42 INFO]: [O'DailyQuests] hardQuests array successfully loaded (9).
# [22:00:42 INFO]: [O'DailyQuests] Plugin is started!
# [22:00:42 INFO]: [Tebex] Enabling Tebex v2.0.5
# [22:00:43 INFO]: [DeluxeMenus] Enabling DeluxeMenus v1.14.0-Release
# [22:00:43 INFO]: [Tebex] Connected to WildCraft - Minecraft: Java Edition server.
# [22:00:43 INFO]: [DeluxeMenus] Successfully hooked into PlaceholderAPI!
# [22:00:43 INFO]: [DeluxeMenus] 7 GUI menus loaded!
# [22:00:43 INFO]: [DeluxeMenus] You are running the latest version of DeluxeMenus!
# [22:00:43 INFO]: [DeluxeMenus] Successfully hooked into Vault!
# [22:00:43 INFO]: [PlaceholderAPI] Successfully registered internal expansion: deluxemenus [1.14.0-Release]
# [22:00:43 INFO]: [Jobs] Enabling Jobs v5.2.4.3
# [22:00:44 INFO]: ------------- Jobs -------------
# [22:00:44 INFO]: [PlaceholderAPI] Successfully registered internal expansion: jobsr [5.2.4.3]
# [22:00:44 INFO]: PlaceholderAPI hooked.
# [22:00:44 INFO]: Connected to database (SqLite)
# [22:00:44 INFO]: Loaded 8 titles
# [22:00:44 INFO]: Loaded 2 restricted areas!
# [22:00:44 INFO]: Loaded 69 protected blocks timers
# [22:00:44 INFO]: Loaded 1402 custom item names
# [22:00:44 INFO]: Loaded 81 custom entity names
# [22:00:44 INFO]: Loaded 2 custom MythicMobs names
# [22:00:44 INFO]: Loaded 40 custom enchant names
# [22:00:44 INFO]: Loaded 21 custom enchant names
# [22:00:44 INFO]: Loaded 16 custom color names
# [22:00:44 INFO]: Update shops items icon section and use 'ItemStack' instead
# [22:00:44 INFO]: Loaded 4 shop items
# [22:00:44 INFO]: Loaded 1 quests for Builder
# [22:00:44 INFO]: Loaded 1 quests for Fisherman
# [22:00:44 INFO]: Loaded 1 quests for Enchanter
# [22:00:44 INFO]: Loaded 1 quests for Digger
# [22:00:44 INFO]: Loaded 1 quests for Weaponsmith
# [22:00:44 INFO]: Loaded 1 quests for Crafter
# [22:00:44 INFO]: Loaded 1 quests for Hunter
# [22:00:44 INFO]: Loaded 1 quests for Explorer
# [22:00:44 INFO]: Loaded 1 quests for Miner
# [22:00:44 INFO]: Loaded 1 quests for Woodcutter
# [22:00:44 INFO]: Loaded 1 quests for Brewer
# [22:00:44 INFO]: Loaded 1 quests for Farmer
# [22:00:44 INFO]: Loaded 12 jobs
# [22:00:44 INFO]: Loaded 0 boosted items
# [22:00:44 INFO]: Loaded 4 furnace for reassigning.
# [22:00:44 INFO]: Loaded 1 brewing for reassigning.
# [22:00:44 INFO]: Started database save task.
# [22:00:44 INFO]: Started buffered payment thread.
# [22:00:44 INFO]: Preloaded 12 players data in 0.0
# [22:00:44 INFO]: Registering listeners...
# [22:00:44 INFO]: Listeners registered successfully
# [22:00:44 INFO]: Plugin has been enabled successfully.
# [22:00:44 INFO]: ------------------------------------
# [22:00:44 INFO]: [EasyCommandBlocker] Enabling EasyCommandBlocker v1.9.3
# [22:00:45 INFO]: [EasyCommandBlocker] Has been enabled! Version: 1.9.3
# [22:00:45 INFO]: [EasyCommandBlocker] Thanks for using my plugin!   ~Ajneb97
# [22:00:45 INFO]: [TAB] Enabling TAB v4.0.3
# [22:00:45 INFO]: [TAB] Server version: 1.20.1 (v1_20_R1)
# [22:00:45 INFO]: [TAB] Loaded NMS hook in 18ms
# [22:00:45 INFO]: [TAB] Enabled in 100ms
# [22:00:45 INFO]: [BetterRTP] Enabling BetterRTP v3.6.13
# [22:00:46 INFO]: [BetterRTP] Cooldown = 300
# [22:00:46 INFO]: [PlaceholderAPI] Successfully registered internal expansion: betterrtp [3.6.13]
# [22:00:46 INFO]: [ProtectionStones] Enabling ProtectionStones v2.10.3
# [22:00:46 INFO]: [WorldGuard] Registering session handler dev.espi.protectionstones.flags.GreetingFlagHandler
# [22:00:46 INFO]: [WorldGuard] Registering session handler dev.espi.protectionstones.flags.FarewellFlagHandler
# [22:00:46 INFO]: [ProtectionStones] PlaceholderAPI support enabled!
# [22:00:46 INFO]: [PlaceholderAPI] Successfully registered internal expansion: protectionstones [2.10.3]
# [22:00:46 INFO]: [ProtectionStones] LuckPerms support enabled!
# [22:00:46 INFO]: [ProtectionStones] Protection Stone Blocks:
# [22:00:46 INFO]: [ProtectionStones] - ANCIENT_DEBRIS (500)
# [22:00:46 INFO]: [ProtectionStones] - EMERALD_ORE (200)
# [22:00:46 INFO]: [ProtectionStones] - IRON_ORE (50)
# [22:00:46 INFO]: [ProtectionStones] - COPPER_ORE (25)
# [22:00:46 INFO]: [ProtectionStones] - GOLD_ORE (100)
# [22:00:46 INFO]: [ProtectionStones] - REDSTONE_ORE (150)
# [22:00:46 INFO]: [ProtectionStones] - DIAMOND_ORE (350)
# [22:00:46 INFO]: [ProtectionStones] Building region cache...
# [22:00:46 INFO]: [ProtectionStones] Building UUID cache... (if slow change async-load-uuid-cache in the config to true)
# [22:00:46 INFO]: [ProtectionStones] Checking if PS regions have been updated to UUIDs...
# [22:00:46 INFO]: [ProtectionStones] §fProtectionStones has successfully started!
# [22:00:46 INFO]: [ChatImage] Enabling ChatImage v2.7.0
# [22:00:47 INFO]: [PlaceholderAPI] Successfully registered internal expansion: chatimage [1.0.0]
# [22:00:47 INFO]: [AngelChest] Enabling AngelChest v13.6.1
# [22:00:47 INFO]: [AngelChest] groups.yml does not exist, skipping custom group settings.
# [22:00:47 INFO]: [AngelChest] blacklist.yml does not exist, disabling item blacklist.
# [22:00:47 INFO]: [AngelChest] Not using premium version, disabling Graveyards feature
# [22:00:47 WARN]: [AngelChest] Could not add usage/description to command acopen
# [22:00:47 INFO]: [PlaceholderAPI] Successfully registered internal expansion: angelchest [GENERIC]
# [22:00:47 INFO]: [AngelChest] Successfully hooked into Vault and the EconomyProvider, enabling economy functions.
# [22:00:47 INFO]: [AngelChest] [ACF] Enabled Asynchronous Tab Completion Support!
# [22:00:47 INFO]: [AngelChest] Successfully enabled AngelChest v13.6.1 (Premium: false)
# [22:00:47 INFO]: [EssentialsSpawn] Enabling EssentialsSpawn v2.20.1
# [22:00:47 INFO]: [EssentialsSpawn] Starting Metrics. Opt-out using the global bStats config.
# [22:00:47 INFO]: [HeadDB] Enabling HeadDB v5.0.0-rc.7
# [22:00:48 INFO]: HeadDB >> [INFO]: Loading HeadDB - 5.0.0-rc.7
# [22:00:48 INFO]: HeadDB >> [INFO]: Loaded 1 languages!
# [22:00:48 INFO]: HeadDB >> [INFO]: Done!
# [22:00:48 INFO]: [PlayerKits2] Enabling PlayerKits2 v1.12.4
# [22:00:48 INFO]: [PlaceholderAPI] Successfully registered internal expansion: playerkits [1.12.4]
# [22:00:48 INFO]: [PlayerKits²] Has been enabled! Version: 1.12.4
# [22:00:48 INFO]: [PlayerKits²] Thanks for using my plugin!   ~Ajneb97
# [22:00:48 INFO]: There is a new version available. (1.12.5)
# [22:00:48 INFO]: You can download it at: https://modrinth.com/plugin/playerkits-2
# [22:00:48 INFO]: [BetterTeams] Enabling BetterTeams v4.9.4
# [22:00:49 INFO]: [BetterTeams] Checking if the file messages.yml is up to date
# [22:00:49 INFO]: [BetterTeams] File is up to date
# [22:00:49 INFO]: [PlaceholderAPI] Successfully registered internal expansion: betterTeams [4.9.4]
# [22:00:49 INFO]: Display team name config value: prefix
# [22:00:49 INFO]: Loading below name. Type: PREFIX
# [22:00:49 INFO]: teamManagement declared: com.booksaw.betterTeams.events.MCTeamManagement@3d3af56b
# [22:00:49 INFO]: [ItemTag] Enabling ItemTag v3.4.2
# [22:00:49 INFO]: [ItemTag] Data using Spigot PersistentDataContainer
# [22:00:49 INFO]: [ItemTag] EquipmentChangeListener
# [22:00:49 INFO]: [ItemTag] Hooking into PlaceholderApi
# [22:00:49 INFO]: [ItemTag] Hooked into PlaceHolderAPI:
# [22:00:49 INFO]: [ItemTag] placeholders:
# [22:00:49 INFO]: [ItemTag]   %itemtag_cooldown_<timeunit>_[cooldownid]%
# [22:00:49 INFO]: [ItemTag]     shows how much cooldown has selected cooldownid for player
# [22:00:49 INFO]: [ItemTag]     <timeunit> may be h, s or ms
# [22:00:49 INFO]: [ItemTag]     [cooldownid] for cooldown type, by default default
# [22:00:49 INFO]: [ItemTag]     example: %itemtag_cooldown_s_anid%
# [22:00:49 INFO]: [ItemTag]   %itemtag_handcooldown_<timeunit>%
# [22:00:49 INFO]: [ItemTag]     shows how much cooldown has player on the item in his hand
# [22:00:49 INFO]: [ItemTag]     <timeunit> may be h, s or ms
# [22:00:49 INFO]: [ItemTag]     example: %itemtag_handcooldown_s%
# [22:00:49 INFO]: [PlaceholderAPI] Successfully registered internal expansion: itemtag [1.0]
# [22:00:49 INFO]: [ItemTag] # Enabled (took 41 ms)
# [22:00:49 INFO]: [SilkSpawners_v2] Enabling SilkSpawners_v2 v2.3.1
# [22:00:49 INFO]: [SilkSpawners] Loading configuration...
# [22:00:49 INFO]: [SilkSpawners] Configuration is up to date
# [22:00:49 INFO]: [SilkSpawners] [INFO]: Starting SilkSpawners v2.3.1
# [22:00:49 INFO]: [SilkSpawners] [INFO]: Loading Cross-Version support
# [22:00:49 INFO]: [SilkSpawners] [INFO]: Checking for updates
# [22:00:49 INFO]: [SilkSpawners] [INFO]: Loaded support for version 1.20.1
# [22:00:49 INFO]: [SilkSpawners] [INFO]: Loading locale file
# [22:00:49 INFO]: [SilkSpawners] [INFO]: Starting bStats integration
# [22:00:49 INFO]: [SilkSpawners] [INFO]: Registering listeners
# [22:00:49 INFO]: [SilkSpawners] [INFO]: Registering commands
# [22:00:49 INFO]: [SilkSpawners] [INFO]: Started SilkSpawners v2.3.1
# [22:00:49 INFO]: [ChatManager] Enabling ChatManager v3.7.7
# [22:00:49 INFO]: [SilkSpawners] [INFO]: The plugin is up to date (Current release v2.3.1)
# [22:00:50 INFO]: [ChatManager] Hooked into: PlaceholderAPI v2.11.6
# [22:00:50 INFO]: [PlaceholderAPI] Successfully registered internal expansion: chatmanager [3.7.7]
# [22:00:50 INFO]: [ChatManager] Hooked into: Essentials v2.20.1
# [22:00:50 INFO]: [ChatManager] Hooked into: Vault v1.7.3-b131
# [22:00:50 INFO]: [ChatManager] Hooked into: DeluxeTags v1.8.2-Release
# [22:00:50 INFO]: [ChatManager] Hooked into: LuckPerms v5.4.102
# [22:00:50 INFO]: [ChatManager] Plugin is up to date - v3.7.7
# [22:00:50 INFO]: [ChatManager] Starting Metrics.
# [22:00:50 INFO]: =========================
# [22:00:50 INFO]: Chat Manager
# [22:00:50 INFO]: Version 3.7.7
# [22:00:50 INFO]: Author: H1DD3NxN1NJA
# [22:00:50 INFO]: =========================
# [22:00:50 INFO]: [DailyRewardsPlus] Enabling DailyRewardsPlus v1.3.3
# [22:00:50 INFO]: [PlaceholderAPI] Successfully registered internal expansion: daily [1.0.0]
# ...
# [00:27:12 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] failed to get Minecraft server from Bukkit.getServer()
# [00:27:12 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] connecting to minecraft server at localhost/127.0.0.1:25565
# [00:27:12 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] connected to local minecraft server
# [00:27:13 INFO]: [gg.playit.minecraft.PlayitManager] got new client: NewClient{connectAddr=209.25.140.194:17182, peerAddr=190.89.31.63:63790, claimAddress=209.25.140.2:43784, claimToken=[44, 0, 60, -47, 25, -116, -62, 67, 30, -66, 89, 31, 63, -7, 46, 81, -80, -116, -13, -85, 8, 102, -4, -109, 97, 0, 0, 0, 0, 0, 10, 34, -40, 0, 0, 0, 0, 0, 52, -10, -23, 118, -13, -85, 8, 0, 0, 0, 0, 45, 0, 0, 0, 0, 0, 0, 0, 1, 0, 2, 64, -64, 102, 52, -66, 40, 56, -47, -49, -19, 52, 23, 111, 122, -29, 35], tunnelServerId=1, dataCenterId=45}
# [00:27:13 INFO]: [gg.playit.minecraft.PlayitManager] starting tcp tunnel for client
# [00:27:13 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] start connection to /209.25.140.2:43784 to claim client
# [00:27:13 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] connected to tunnel server, sending claim token
# [00:27:13 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] claim token sent
# [00:27:13 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] connection to tunnel server has been established
# [00:27:13 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] Reflect: ReflectionHelper{ServerConnection=class net.minecraft.server.network.ServerConnection, LegacyPingHandler=class net.minecraft.server.network.LegacyPingHandler, MinecraftServer=class net.minecraft.server.MinecraftServer, PacketSplitter=class net.minecraft.network.PacketSplitter, PacketDecoder=class net.minecraft.network.PacketDecoder, EnumProtocolDirection=class net.minecraft.network.protocol.EnumProtocolDirection, PacketPrepender=class net.minecraft.network.PacketPrepender, PacketEncoder=class net.minecraft.network.PacketEncoder, NetworkManagerServer=class net.minecraft.network.NetworkManagerServer, NetworkManager=class net.minecraft.network.NetworkManager, HandshakeListener=class net.minecraft.server.network.HandshakeListener, PacketListener=interface net.minecraft.network.PacketListener, CraftServer=null}
# [00:27:13 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] failed to get Minecraft server from Bukkit.getServer()
# [00:27:13 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] connecting to minecraft server at localhost/127.0.0.1:25565
# [00:27:13 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] connected to local minecraft server
# [00:27:13 WARN]: [gg.playit.minecraft.PlayitTcpTunnel] failed to send data to tunnel
# [00:27:13 WARN]: [gg.playit.minecraft.PlayitTcpTunnel] failed to send data to tunnel
# [00:27:13 INFO]: UUID of player DasVicgeta is 7e385908-e08e-3ca0-ac21-29b5090dec62
# [00:27:13 INFO]: [TAB] ViaVersion returned unknown protocol version 767 for player DasVicgeta. This may result in plugin not working correctly for them.
# [00:27:13 INFO]: DasVicgeta[/127.0.0.1:52154] logged in with entity id 59710 at ([spawn]362.6444919223313, 101.84900079226159, -13.86057433929785)
# [00:27:14 INFO]: [O'DailyQuests] DasVicgeta's quests have been loaded.
# [00:27:16 INFO]: [Not Secure] [SIGMA] i(♛)i HELPER  karlito101 ➤ como?
# [00:27:18 INFO]: [nLogin] The user DasVicgeta has successfully logged in.
# [00:27:19 INFO]: [Not Secure]  Guardian++  saquiador3000 ➤ hasme tp a el
# [00:27:19 INFO]: DasVicgeta issued server command: /stop
# [00:27:19 WARN]: [O'DailyQuests] Server is stopping. The datas will be saved in synchronous mode.
# [00:27:19 WARN]: [O'DailyQuests] If you think this is a mistake, please contact the developer!
# [00:27:19 INFO]: [DasVicgeta: Stopping the server]
# [00:27:19 INFO]: Stopping server
# [00:27:19 INFO]: [PluginPortal] Disabling PluginPortal v2.0.4
# [00:27:19 INFO]: [AuraSkills] Disabling AuraSkills v2.2.3
# [00:27:20 INFO]: [CommandPanels] Disabling CommandPanels v3.21.4.2
# [00:27:20 INFO]: RockyHawk's CommandPanels Plugin Disabled, aww man.
# [00:27:20 INFO]: [AuctionHouse] Disabling AuctionHouse v3.5
# [00:27:20 INFO]: [PlaceholderAPI] Unregistered placeholder expansion auctionhouse
# [00:27:20 INFO]: [PlaceholderAPI] Reason: required plugin AuctionHouse was disabled.
# [00:27:20 INFO]: [AuctionHouse] Saving auctions data
# [00:27:20 INFO]: [ajLeaderboards] Disabling ajLeaderboards v2.9.0
# [00:27:20 INFO]: [ajLeaderboards] Shutting down cache method..
# [00:27:20 INFO]: [ajLeaderboards] Cache method shut down
# [00:27:20 INFO]: [ajLeaderboards] Killing remaining workers
# [00:27:20 INFO]: [ajLeaderboards] Remaining workers killed
# [00:27:20 INFO]: [ajLeaderboards] ajLeaderboards v2.9.0 disabled.
# [00:27:20 INFO]: [CustomCrafting] Disabling CustomCrafting v4.16.9
# [00:27:20 INFO]: [nLogin] Disabling nLogin v10.3.28
# [00:27:20 INFO]: [nLogin] Successful plugin core shutdown (took 0.00s)
# [00:27:20 INFO]: [LuckyTreasure] Disabling LuckyTreasure v4.2
# [00:27:20 INFO]: [LuckyTreasure] ===============================
# [00:27:20 INFO]: [LuckyTreasure] §6The plugin is created by §dLAMMA
# [00:27:20 INFO]: [LuckyTreasure]   You can find me in §cDiscord
# [00:27:20 INFO]: [LuckyTreasure] ===============================
# [00:27:20 INFO]: [LuckyTreasure] Discord_ID: §dLAMMA#7870
# [00:27:20 INFO]: [ClearLag] Disabling ClearLag v3.2.2
# [00:27:20 INFO]: [ClearLag] Clearlag is now disabled!
# [00:27:20 INFO]: [Chunky] Disabling Chunky v1.3.146
# [00:27:20 INFO]: [ConditionalEvents] Disabling ConditionalEvents v4.57.3
# [00:27:20 INFO]: [ConditionalEvents] Has been disabled! Version: 4.57.3
# [00:27:20 INFO]: [FancyHolograms] Disabling FancyHolograms v2.3.3
# [00:27:20 INFO]: [playit-gg] Disabling playit-gg v0.1.4
# [00:27:20 INFO]: [ExcellentCrates] Disabling ExcellentCrates v5.0.0
# [00:27:20 INFO]: [com.zaxxer.hikari.HikariDataSource] HikariPool-2 - Shutdown initiated...
# [00:27:20 INFO]: [com.zaxxer.hikari.HikariDataSource] HikariPool-2 - Shutdown completed.
# [00:27:20 INFO]: [CustomDeathMessages] Disabling CustomDeathMessages v2.0.1
# [00:27:20 INFO]: [CommandBlocks] Disabling CommandBlocks v1.3.2
# [00:27:20 INFO]: [DailyRewardsPlus] Disabling DailyRewardsPlus v1.3.3
# [00:27:20 INFO]: [DailyRewards+] Cleaning up...
# [00:27:20 INFO]: [ChatManager] Disabling ChatManager v3.7.7
# [00:27:20 INFO]: [PlaceholderAPI] Unregistered placeholder expansion chatmanager
# [00:27:20 INFO]: [PlaceholderAPI] Reason: required plugin ChatManager was disabled.
# [00:27:20 INFO]: [SilkSpawners_v2] Disabling SilkSpawners_v2 v2.3.1
# [00:27:20 INFO]: [SilkSpawners] [INFO]: Stopping version checker
# [00:27:20 INFO]: [ItemTag] Disabling ItemTag v3.4.2
# [00:27:20 INFO]: [PlaceholderAPI] Unregistered placeholder expansion itemtag
# [00:27:20 INFO]: [PlaceholderAPI] Reason: required plugin ItemTag was disabled.
# [00:27:20 INFO]: [BetterTeams] Disabling BetterTeams v4.9.4
# [00:27:20 INFO]: [PlayerKits2] Disabling PlayerKits2 v1.12.4
# [00:27:20 INFO]: [PlayerKits²] Has been disabled! Version: 1.12.4
# [00:27:20 INFO]: [HeadDB] Disabling HeadDB v5.0.0-rc.7
# [00:27:20 INFO]: [EssentialsSpawn] Disabling EssentialsSpawn v2.20.1
# [00:27:20 INFO]: [AngelChest] Disabling AngelChest v13.6.1
# [00:27:20 INFO]: [ChatImage] Disabling ChatImage v2.7.0
# [00:27:20 INFO]: [ProtectionStones] Disabling ProtectionStones v2.10.3
# [00:27:20 INFO]: [nightcore] Disabling nightcore v2.5.2
# [00:27:20 INFO]: [TAB] Disabling TAB v4.0.3
# [00:27:20 INFO]: [TAB] Disabled in 2ms
# [00:27:20 INFO]: [EasyCommandBlocker] Disabling EasyCommandBlocker v1.9.3
# [00:27:20 INFO]: [EasyCommandBlocker] Has been disabled! Version: 1.9.3
# [00:27:20 INFO]: [Jobs] Disabling Jobs v5.2.4.3
# [00:27:20 INFO]: ------------- Jobs -------------
# [00:27:20 INFO]: Cleared boss bar cache
# [00:27:20 INFO]: Database save task shutdown!
# [00:27:20 INFO]: Buffered payment thread shutdown.
# [00:27:20 INFO]: Saved player data
# [00:27:20 INFO]: Closed database connection
# [00:27:20 INFO]: ------------------------------------
# [00:27:20 INFO]: [DeluxeMenus] Disabling DeluxeMenus v1.14.0-Release
# [00:27:20 INFO]: [Tebex] Disabling Tebex v2.0.5
# [00:27:20 INFO]: [O'DailyQuests] Disabling ODailyQuests v2.2.5
# [00:27:20 INFO]: [O'DailyQuests] saquiador3000's data saved.
# [00:27:20 INFO]: [O'DailyQuests] karlito101's data saved.
# [00:27:20 INFO]: [O'DailyQuests] DasVicgeta's data saved.
# [00:27:20 INFO]: [com.zaxxer.hikari.HikariDataSource] HikariPool-1 - Shutdown initiated...
# [00:27:20 INFO]: [com.zaxxer.hikari.HikariDataSource] HikariPool-1 - Shutdown completed.
# [00:27:20 INFO]: [O'DailyQuests] §cPlugin is shutting down...
# [00:27:20 INFO]: [YamipaPlugin] Disabling YamipaPlugin v1.3.1
# [00:27:20 INFO]: [SkinsRestorer] Disabling SkinsRestorer v15.4.3
# [00:27:20 INFO]: [WolfyUtilities] Disabling WolfyUtilities v4.16.15
# [00:27:20 INFO]: [WolfyUtilities] Save stored Custom Items
# [00:27:20 INFO]: [FancyNpcs] Disabling FancyNpcs v2.2.0.175
# [00:27:20 INFO]: [NexEngine] Disabling NexEngine v2.2.12
# [00:27:20 INFO]: [DeluxeTags] Disabling DeluxeTags v1.8.2-Release
# [00:27:20 INFO]: [ItemEdit] Disabling ItemEdit v3.4.2
# [00:27:20 INFO]: [PlaceholderAPI] Unregistered placeholder expansion itemedit
# [00:27:20 INFO]: [PlaceholderAPI] Reason: required plugin ItemEdit was disabled.
# [00:27:20 INFO]: [CMILib] Disabling CMILib v1.5.1.0
# [00:27:20 INFO]: [Essentials] Disabling Essentials v2.20.1
# [00:27:20 INFO]: [Vault] [Economy] Essentials Economy unhooked.
# [00:27:20 INFO]: [ProtocolLib] Disabling ProtocolLib v5.2.0-SNAPSHOT-679
# [00:27:20 INFO]: [MythicMobs] Disabling MythicMobs v5.7.2-${CI_COMMIT_SHORT_SHA}
# [00:27:20 INFO]: [MythicMobs] ------------------------------------------------------------
# [00:27:20 INFO]: [MythicMobs] -
# [00:27:20 INFO]: [MythicMobs] - Unloading Mythic...
# [00:27:20 INFO]: [MythicMobs] -
# [00:27:20 INFO]: [MythicMobs] ------------------------------------------------------------
# [00:27:20 INFO]: [MythicMobs] - Spawners saved and unloaded...
# [00:27:20 WARN]: [gg.playit.minecraft.PlayitTcpTunnel] failed to send data to tunnel
# [00:27:20 INFO]: [MythicMobs] - Mobs saved and unloaded...
# [00:27:20 INFO]: [MythicMobs] Saving plugin data...
# [00:27:20 INFO]: [MythicMobs] ✓Saving Finished
# [00:27:20 INFO]: [MythicMobs] - Variables saved...
# [00:27:20 INFO]: [MythicMobs] - All active settings have been saved!
# [00:27:20 INFO]: [MythicMobs] - Mythic has been unloaded!
# [00:27:20 INFO]: [MythicMobs] ------------------------------------------------------------
# [00:27:20 INFO]: [MythicMobs] Saving plugin data...
# [00:27:20 INFO]: [MythicMobs] ✓Saving Finished
# [00:27:20 INFO]: [ShopGUIPlus] Disabling ShopGUIPlus v1.94.0
# [00:27:20 INFO]: [HolographicDisplays] Disabling HolographicDisplays v3.0.4
# [00:27:20 INFO]: [Multiverse-Core] Disabling Multiverse-Core v4.3.11
# [00:27:20 INFO]: [WorldGuard] Disabling WorldGuard v7.0.9+5934e49
# [00:27:20 INFO]: [WorldGuard] Shutting down executor and cancelling any pending tasks...
# [00:27:20 INFO]: [PlaceholderAPI] Disabling PlaceholderAPI v2.11.6
# [00:27:20 INFO]: [VoidGen] Disabling VoidGen v2.2.1
# [00:27:20 INFO]: [WorldEdit] Disabling WorldEdit v7.2.20+6667-f0f1e66
# [00:27:20 INFO]: Unregistering com.sk89q.worldedit.bukkit.BukkitServerInterface from WorldEdit
# [00:27:20 INFO]: [Vault] Disabling Vault v1.7.3-b131
# [00:27:20 INFO]: [LuckPerms] Disabling LuckPerms v5.4.102
# [00:27:20 INFO]: [LuckPerms] Starting shutdown process...
# [00:27:20 INFO]: [LuckPerms] Closing storage...
# [00:27:20 INFO]: [LuckPerms] Goodbye!
# [00:27:20 INFO]: [ViaVersion] Disabling ViaVersion v5.0.3
# [00:27:20 INFO]: [ViaVersion] ViaVersion has been disabled; uninjected the platform and shut down the scheduler.
# [00:27:20 INFO]: Saving players
# [00:27:20 INFO]: saquiador3000 lost connection: Server closed
# [00:27:20 INFO]: saquiador3000 left the game
# [00:27:20 INFO]: karlito101 lost connection: Server closed
# [00:27:20 WARN]: [gg.playit.minecraft.PlayitTcpTunnel] failed to send data to minecraft server
# [00:27:20 INFO]: karlito101 left the game
# [00:27:20 INFO]: DasVicgeta lost connection: Server closed
# [00:27:20 WARN]: [gg.playit.minecraft.PlayitTcpTunnel] failed to send data to minecraft server
# [00:27:20 INFO]: DasVicgeta left the game
# [00:27:21 INFO]: Saving worlds
# [00:27:21 INFO]: Saving chunks for level 'ServerLevel[world]'/minecraft:overworld
# [00:27:21 INFO]: [ChunkHolderManager] Waiting 60s for chunk system to halt for world 'world'
# [00:27:21 INFO]: [ChunkHolderManager] Halted chunk system for world 'world'
# [00:27:21 INFO]: [ChunkHolderManager] Saving all chunkholders for world 'world'
# [00:27:21 INFO]: [ChunkHolderManager] Saved 5 block chunks, 84 entity chunks, 0 poi chunks in world 'world' in 0.02s
# [00:27:22 INFO]: [gg.playit.minecraft.PlayitManager] control channel shutdown
# [00:27:23 INFO]: ThreadedAnvilChunkStorage (world): All chunks are saved
# [00:27:23 INFO]: Saving chunks for level 'ServerLevel[world_nether]'/minecraft:the_nether
# [00:27:23 INFO]: [ChunkHolderManager] Waiting 60s for chunk system to halt for world 'world_nether'
# [00:27:23 INFO]: [ChunkHolderManager] Halted chunk system for world 'world_nether'
# [00:27:23 INFO]: [ChunkHolderManager] Saving all chunkholders for world 'world_nether'
# [00:27:23 INFO]: [ChunkHolderManager] Saved 5 block chunks, 24 entity chunks, 0 poi chunks in world 'world_nether' in 0.01s
# [00:27:23 INFO]: ThreadedAnvilChunkStorage (DIM-1): All chunks are saved
# [00:27:23 INFO]: Saving chunks for level 'ServerLevel[world_the_end]'/minecraft:the_end
# [00:27:23 INFO]: [ChunkHolderManager] Waiting 60s for chunk system to halt for world 'world_the_end'
# [00:27:23 INFO]: [ChunkHolderManager] Halted chunk system for world 'world_the_end'
# [00:27:23 INFO]: [ChunkHolderManager] Saving all chunkholders for world 'world_the_end'
# [00:27:23 INFO]: [ChunkHolderManager] Saved 2 block chunks, 16 entity chunks, 0 poi chunks in world 'world_the_end' in 0.00s
# [00:27:23 INFO]: ThreadedAnvilChunkStorage (DIM1): All chunks are saved
# [00:27:23 INFO]: Saving chunks for level 'ServerLevel[spawn]'/minecraft:spawn
# [00:27:23 INFO]: [ChunkHolderManager] Waiting 60s for chunk system to halt for world 'spawn'
# [00:27:23 INFO]: [ChunkHolderManager] Halted chunk system for world 'spawn'
# [00:27:23 INFO]: [ChunkHolderManager] Saving all chunkholders for world 'spawn'
# [00:27:23 INFO]: [ChunkHolderManager] Saved 274 block chunks, 23 entity chunks, 0 poi chunks in world 'spawn' in 0.08s
# [00:27:24 INFO]: ThreadedAnvilChunkStorage (spawn): All chunks are saved
# [00:27:24 INFO]: Saving chunks for level 'ServerLevel[test]'/minecraft:test
# [00:27:24 INFO]: [ChunkHolderManager] Waiting 60s for chunk system to halt for world 'test'
# [00:27:24 INFO]: [ChunkHolderManager] Halted chunk system for world 'test'
# [00:27:24 INFO]: [ChunkHolderManager] Saving all chunkholders for world 'test'
# [00:27:24 INFO]: [ChunkHolderManager] Saved 0 block chunks, 37 entity chunks, 0 poi chunks in world 'test' in 0.01s
# [00:27:24 INFO]: ThreadedAnvilChunkStorage (test): All chunks are saved
# [00:27:24 INFO]: ThreadedAnvilChunkStorage: All dimensions are saved
# [00:27:24 INFO]: Flushing Chunk IO
# [00:27:24 INFO]: Closing Thread Pool
# > 2024-10-02 00:27:24,234 Log4j2-AsyncAppenderEventDispatcher-1-Async WARN Advanced terminal features are not available in this environment
# [00:27:24 INFO]: Closing Server
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 261
#     258 # Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto
#     260 while True:
# --> 261     time.sleep(60)
#
# KeyboardInterrupt:
